# %%
### Read a whole file

with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# hello bhai
# kaisa hai
# mera nam kher chdo kya hi bolna
# bekr hu mai
# lol
# hehehehehehe
# i am the worst and i gotta study

# %%
### read a file line by line

with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# This is a new line.
# This will overwrite the existing content.
# This line will be appended to the file.
# Another appended line.

# %%
## writing a file (overwrtiting 

with open ('example.txt', 'w') as file:
    file.write("This is a new line.\n")
    file.write("This will overwrite the existing content.\n")

# %%
## write a file without overwriting (appending)

with open('example.txt', 'a') as file:
    file.write("This line will be appended to the file.\n")
    file.write("Another appended line.\n")

# %%
## binary files 

data = b'\x00\x01\x02\x03\x04\x05'
with open('binary_file.bin', 'wb') as file:
    file.write(data)

# %%
with open('binary_file.bin', 'rb') as file:
    binary_content = file.read()
    print(binary_content)
# Out:
# b'\x00\x01\x02\x03\x04\x05'

# %%
## read a text file and count the number of lines, words, and characters

def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path = 'example.txt'
lines, words, characters = count_text_file(file_path)
print(f"Lines: {lines}, Words: {words}, Characters: {characters}")
# Out:
# Lines: 4, Words: 22, Characters: 125
